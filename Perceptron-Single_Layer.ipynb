# %%
import pandas as pd

# %%
import numpy

# %%
placement = pd.read_csv(r"C:\Users\HP\Desktop\Deep Learning\Session-2\placement.csv")

# %%
placement.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
print(placement.shape)
# Out:
# (100, 3)

# %%
placement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
print(placement.sample(5))
# Out:
#     cgpa  resume_score  placed
# 74  5.54          7.36       0
# 36  8.16          7.56       1
# 81  6.12          6.72       0
# 43  8.21          7.95       1
# 53  6.00          7.16       0

# %%
placement.tail(5)
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ------------------------------- ------ 41.0/48.7 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 48.7/48.7 kB 610.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/385.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/385.0 MB 5.5 MB/s eta 0:01:11
#    ---------------------------------------- 0.1/385.0 MB 5.5 MB/s eta 0:01:11
#    ---------------------------------------- 0.2/385.0 MB 1.3 MB/s eta 0:04:54
#    ---------------------------------------- 0.2/385.0 MB 1.4 MB/s eta 0:04:40
#    ---------------------------------------- 0.2/385.0 MB 1.1 MB/s eta 0:05:58
#    ---------------------------------------- 0.5/385.0 MB 1.6 MB/s eta 0:03:55
#    ---------------------------------------- 0.5/385.0 MB 1.6 MB/s eta 0:03:55
# ...

# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf._version_}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd._version_}")
print(f"Scikit-Learn {sk._version_}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Windows-10-10.0.22631-SP0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       7 import platform
#       9 print(f"Python Platform: {platform.platform()}")
# ---> 10 print(f"Tensor Flow Version: {tf._version_}")
#      11 print()
#      12 print(f"Python {sys.version}")
#
# AttributeError: module 'tensorflow' has no attribute '_version_'

# %%
import sys
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"TensorFlow Version: {tf.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Windows-10-10.0.22631-SP0
# TensorFlow Version: 2.17.0
#
# Python 3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]
# Pandas 2.1.4
# Scikit-Learn 1.2.2
# GPU is NOT AVAILABLE

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.scatterplot(x=placement.cgpa,y=placement.resume_score,hue=placement.placed)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = placement.iloc[:,0:2]
y = placement.iloc[:,-1]

# %%
X
# Out:
#     cgpa  resume_score
# 0   8.14          6.52
# 1   6.17          5.17
# 2   8.27          8.86
# 3   6.88          7.27
# 4   7.52          7.30
# ..   ...           ...
# 95  6.33          6.38
# 96  8.23          7.76
# 97  6.65          7.78
# 98  8.14          5.63
# 99  6.09          6.61
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 217.9 kB/s eta 0:00:07
#     --------------------------------------- 0.0/1.4 MB 217.9 kB/s eta 0:00:07
#    - -------------------------------------- 0.0/1.4 MB 245.8 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/1.4 MB 351.4 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.4 MB 479.3 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 479.3 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.4 MB 595.3 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.4 MB 729.6 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.4 MB 849.3 kB/s eta 0:00:02
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
